# %% [markdown]
# 1. IMPORTING LIBRARIES
# 2. LOADING DATA
# 3. EXPLORING DATA
# 4. EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("D:\\DL\\supermarket_sales - Sheet1.csv")

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.isna()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
data = data.drop('Invoice ID', axis=1)
data
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
# I am describing data again to see much clear results to match with histogram.
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# # Analysing by Branches of the supermarket

# %%
sns.set_style('darkgrid')
sns.countplot(y='Gender',hue='Branch',data=data,palette='RdBu', saturation=1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gender'>

# %%
sns.set_style('whitegrid')
sns.countplot(y='Customer type',hue='Branch',data=data,palette='RdBu_r', saturation=1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Customer type'>

# %%
data['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
sns.set_style('darkgrid')
sns.countplot(y='Product line',hue='Branch',data=data,palette='RdBu_r', saturation=1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
data_branch_product = data.groupby('Branch')['Product line'].value_counts()
print(data_branch_product)
data1 = data_branch_product.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  Product line
# A       Home and lifestyle        65
#         Electronic accessories    60
#         Sports and travel         59
#         Food and beverages        58
#         Fashion accessories       51
#         Health and beauty         47
# B       Fashion accessories       62
#         Sports and travel         62
#         Electronic accessories    55
#         Health and beauty         53
#         Food and beverages        50
#         Home and lifestyle        50
# C       Food and beverages        66
#         Fashion accessories       65
#         Electronic accessories    55
#         Health and beauty         52
#         Home and lifestyle        45
#         Sports and travel         45
# Name: Product line, dtype: int64

# %%
data_branch_gender = data.groupby('Branch')['Gender'].value_counts()
print(data_branch_gender)
data1 = data_branch_gender.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  Gender
# A       Male      179
#         Female    161
# B       Male      170
#         Female    162
# C       Female    178
#         Male      150
# Name: Gender, dtype: int64

# %%
data_branch_cus_type = data.groupby('Branch')['Customer type'].value_counts()
print(data_branch_cus_type)
data1 = data_branch_cus_type.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  Customer type
# A       Normal           173
#         Member           167
# B       Normal           167
#         Member           165
# C       Member           169
#         Normal           159
# Name: Customer type, dtype: int64

# %%
data_branch_pay = data.groupby('Branch')['Payment'].value_counts()
print(data_branch_pay)
data1 = data_branch_pay.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  Payment
# A       Ewallet        126
#         Cash           110
#         Credit card    104
# B       Ewallet        113
#         Cash           110
#         Credit card    109
# C       Cash           124
#         Ewallet        106
#         Credit card     98
# Name: Payment, dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['Time'] = pd.to_datetime(data['Time'])
data['day'] = (data['Date']).dt.day
#data['day'] = pd.to_datetime(df['day'])
data['weekday'] = (data['Date']).dt.weekday
data['month'] = (data['Date']).dt.month
data['year'] = (data['Date']).dt.year
data['hour'] = (data['Time']).dt.hour
data.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date  ...      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05  ...      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08  ...         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  ...  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27  ...      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08  ...      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  day  weekday  month  year  \
# ...

# %%
data['weekday'].value_counts()
# Out:
# 5    164
# 1    158
# 2    143
# 4    139
# 3    138
# 6    133
# 0    125
# Name: weekday, dtype: int64

# %%
data_branch_weekday = data.groupby('Branch')['weekday'].value_counts()
print(data_branch_weekday)
data1 = data_branch_weekday.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  weekday
# A       6          52
#         1          51
#         4          50
#         5          50
#         0          48
#         3          46
#         2          43
# B       5          60
#         1          53
#         4          51
#         2          50
#         3          44
#         0          39
#         6          35
# C       1          54
#         5          54
#         2          50
#         3          48
#         6          46
#         0          38
#         4          38
# Name: weekday, dtype: int64

# %%
data_branch_hour = data.groupby('Branch')['hour'].value_counts()
print(data_branch_hour)
data1 = data_branch_hour.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  hour
# A       10      38
#         15      37
#         11      35
#         12      33
#         18      33
#         16      32
#         13      31
#         17      27
#         19      27
#         14      25
#         20      22
# B       19      50
#         13      38
#         18      35
#         11      33
#         15      32
#         14      30
#         10      26
#         20      26
#         12      25
#         17      20
#         16      17
# C       10      37
#         19      36
#         13      34
#         15      33
#         12      31
#         14      28
#         16      28
#         17      27
#         20      27
#         18      25
#         11      22
# Name: hour, dtype: int64

# %%
data_branch_month = data.groupby('Branch')['month'].value_counts()
print(data_branch_month)
data1 = data_branch_month.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  month
# A       3        127
#         1        119
#         2         94
# B       3        112
#         1        111
#         2        109
# C       1        122
#         3        106
#         2        100
# Name: month, dtype: int64

# %%
data_branch_year = data.groupby('Branch')['year'].value_counts()
print(data_branch_year)
data1 = data_branch_year.unstack()
data1.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch  year
# A       2019    340
# B       2019    332
# C       2019    328
# Name: year, dtype: int64

# %%
data.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date  ...      Payment    cogs  \
# 0         7  26.1415  548.9715 2019-01-05  ...      Ewallet  522.83
# 1         5   3.8200   80.2200 2019-03-08  ...         Cash   76.40
# 2         7  16.2155  340.5255 2019-03-03  ...  Credit card  324.31
# 3         8  23.2880  489.0480 2019-01-27  ...      Ewallet  465.76
# 4         7  30.2085  634.3785 2019-02-08  ...      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  day  weekday  month  year  \
# ...

# %%
data_branch_unitp = data.groupby('Branch')['Unit price'].sum()
print(data_branch_unitp)
#data1 = data_branch_unitp.unstack()
data_branch_unitp.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    18625.49
# B    18478.88
# C    18567.76
# Name: Unit price, dtype: float64

# %%
data_branch_tax = data.groupby('Branch')['Tax 5%'].sum()
print(data_branch_tax)
#data1 = data_branch_unitp.unstack()
data_branch_tax.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: Tax 5%, dtype: float64

# %%
data_branch_q = data.groupby('Branch')['Quantity'].sum()
print(data_branch_q)
#data1 = data_branch_unitp.unstack()
data_branch_q.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    1859
# B    1820
# C    1831
# Name: Quantity, dtype: int64

# %%
data_branch_total = data.groupby('Branch')['Total'].sum()
print(data_branch_total)
#data1 = data_branch_unitp.unstack()
data_branch_total.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
data_branch_cogs = data.groupby('Branch')['cogs'].sum()
print(data_branch_cogs)
#data1 = data_branch_unitp.unstack()
data_branch_cogs.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    101143.21
# B    101140.64
# C    105303.53
# Name: cogs, dtype: float64

# %%
data_branch_gmp = data.groupby('Branch')['gross margin percentage'].sum()
print(data_branch_gmp)
#data1 = data_branch_unitp.unstack()
data_branch_gmp.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    1619.047619
# B    1580.952381
# C    1561.904762
# Name: gross margin percentage, dtype: float64

# %%
data_branch_gi = data.groupby('Branch')['gross income'].sum()
print(data_branch_gi)
#data1 = data_branch_unitp.unstack()
data_branch_gi.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %%
data_branch_rating = data.groupby('Branch')['Rating'].sum()
print(data_branch_rating)
#data1 = data_branch_unitp.unstack()
data_branch_rating.plot(kind='bar', figsize=(7, 5))
plt.ylabel('count')
plt.show()
# Out:
# Branch
# A    2389.2
# B    2263.6
# C    2319.9
# Name: Rating, dtype: float64

# %%
genderCount  = sns.lineplot(x="hour",  y = 'Quantity',data =data).set_title("Product Sales per Hour")

# %%
genderCount  = sns.relplot(x="hour",  y = 'Quantity', col= 'month' , row= 'Branch', kind="line", hue="Gender", style="Gender", data =data)

# %%
genderCount  = sns.relplot(x="hour",  y = 'Total', col= 'month' , row= 'Branch', estimator = None, kind="line", data =data)

# %%
ageDisSpend = sns.lineplot(x="Total", y = "Rating", data =data)

# %%
sns.heatmap(data.corr())
data.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
# day                        0.057021 -0.043347 -0.002515 -0.002515 -0.002515
# weekday                   -0.007040  0.054770  0.038809  0.038809  0.038809
# month                     -0.027387 -0.014524 -0.022301 -0.022301 -0.022301
# ...
